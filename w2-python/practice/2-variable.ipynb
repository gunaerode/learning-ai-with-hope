# %%
num1=10

# %%
num2=20

# %%
add = num1 + num2

# %%
print(add)
# Out:
# 30

# %%
your name = "Guna"
# Out:
#   Cell In[5], line 1
#     your name = "Guna"
#          ^
# SyntaxError: invalid syntax

# %%
yourName = "Guna"

# %%
print(yourName)
# Out:
# Guna

# %%
age=77
yourName="Guna"

# %%
print("Age:", age, "Name:", yourName)
# Out:
# Age: 77 Name: Guna

# %%
num1=input("Enter num1:")
num2=input("Enter num2:")
total=num1+num2
print(num1+num2)
# Out:
# Enter num1: 20
# Enter num2: 88
# 2088

# %%
num1=int(input("Enter num1:"))
num2=int(input("Enter num2:"))
total=num1+num2
print(num1+num2)
# Out:
# Enter num1: 80
# Enter num2: 29
# 109

# %%
print("Test error
# Out:
#   Cell In[13], line 1
#     print("Test error
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
num1=int(input("Enter num1:")
# Out:
#   Cell In[14], line 1
#     num1=int(input("Enter num1:")
#                                  ^
# _IncompleteInputError: incomplete input

# %%
num1=int(input("Testing run issue with *"))
# Out:
# Testing run issue with * d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num1=int(input("Testing run issue with *"))
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
num1=int(input("Testing run issue with *"))
# Out:
# Testing run issue with * 8283

# %%
print(num1)
# Out:
# 8283
