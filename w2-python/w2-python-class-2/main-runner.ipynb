# %%
from operation import (
    SubfieldsInAI,
    OddEven,
    EligibilityForMarriage,
    FindPercent,
    Triangle
)

# ================= Sub-fields in AI =================
subfields = [
    "Machine Learning",
    "Neural Networks",
    "Vision",
    "Robotics",
    "Speech Processing",
    "Natural Language Processing"
]
SubfieldsInAI.subfields(subfields)

print("---------------")

# ================= Odd or Even =================
print("Title: Odd or Even")
try:
    number = int(input("Enter a number: "))
    OddEven.check(number)
except ValueError:
    print("Please enter a valid integer")

print("---------------")

# ================= Marriage Eligibility =================
print("Title: Marriage Eligibility")
try:
    gender = input("Your Gender: ")
    age = int(input("Your Age: "))
    EligibilityForMarriage.eligible(gender, age)
except ValueError:
    print("Invalid age input")

print("---------------")

# ================= Percentage =================
subjects = {
    "Subject1": 98,
    "Subject2": 87,
    "Subject3": 95,
    "Subject4": 95,
    "Subject5": 93
}
FindPercent.percentage(subjects)

print("---------------")

# ================= Triangle =================

try:
    print("Title: Triangle (Area)")
    height = float(input("Enter height: "))
    breadth = float(input("Enter breadth: "))
    Triangle.area(height, breadth)

    print("---------------")

    print("Title: Triangle (Perimeter)")
    h1 = float(input("Enter height1: "))
    h2 = float(input("Enter height2: "))
    b = float(input("Enter breadth: "))
    Triangle.perimeter(h1, h2, b)
except ValueError:
    print("Please enter valid numbers")
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# ---------------
# Title: Odd or Even
# Enter a number:  52452
# 52452 is Even number
# ---------------
# Title: Marriage Eligibility
# Your Gender:  Male
# Your Age:  20
# NOT ELIGIBLE
# ---------------
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.60000000000001
# ---------------
# Title: Triangle (Area)
# Enter height:  32
# Enter breadth:  34
# Height:32.0
# Breadth:34.0
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# ---------------
# Title: Triangle (Perimeter)
# Enter height1:  2
# Enter height2:  4
# Enter breadth:  4
# Height1:2.0
# Height2:4.0
# Breadth:4.0
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10.0
