# %%
#if
if():
    print()

# %%
age=int(input("Enter your age:"));
# Out:
# Enter your age: 18

# %%
if(age == 18):
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
condition="Just print this text"
if(condition):
    print(condition)
# Out:
# Just print this text
