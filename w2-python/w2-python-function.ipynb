# %%
subFields = [
    "Machine Learning",
    "Neural Networks",
    "Vision",
    "Robotics",
    "Speech Processing",
    "Natural Language Processing"
]

print("Sub-fields in AI are:")
for field in subFields:
    print(field)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Odd or Even
num = int(input("Enter a number: "))

if (num % 2 == 0):
    print(f"{num} is Even number")
else:
    print(f"{num} is Odd number")
# Out:
# Enter a number:  77
# 77 is Odd number

# %%
# Marriage Eligibility
print("Eligibility")
try:
    userGender = input("Your Gender: ").lower()
    userAge = int(input("Your Age: "))
    
    isEligible = (
        (userGender == "male" and userAge >= 21) or
        (userGender == "female" and userAge >= 18)
    )
    
    if (isEligible):
        print("ELIGIBLE")
    else:
        print("NOT ELIGIBLE")
except ValueError as error:
    print(f"Error: {error}")
# Out:
# Eligibility
# Your Gender:  MALE
# Your Age:  21
# ELIGIBLE

# %%
# 10th mark - Percentage
subjects = {
    "Subject1": 98,
    "Subject2": 87,
    "Subject3": 95,
    "Subject4": 95,
    "Subject5": 93
}

total = sum(subjects.values())
percentage = (total / 500) * 100

for subject, marks in subjects.items():
    print(f"{subject}= {marks}")

print(f"Total : {total}")
print(f"Percentage : {percentage}")
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage : 93.60000000000001

# %%
# Area and Perimeter of Triangle
# ====== Area of Triangle
height = 32
breadth = 34

print(f"Height:{height}")
print(f"Breadth:{breadth}")
print("Area formula: (Height*Breadth)/2")

area = (height * breadth) / 2
print(f"Area of Triangle: {area}")

# ====== Perimeter of Triangle =======
height1 = 2
height2 = 4
breadth = 4

print(f"Height1:{height1}")
print(f"Height2:{height2}")
print(f"Breadth:{breadth}")
print("Perimeter formula: Height1+Height2+Breadth")

perimeter = height1 + height2 + breadth
print(f"Perimeter of Triangle: {perimeter}")
# Out:
# Height:32
# Breadth:34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1:2
# Height2:4
# Breadth:4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
